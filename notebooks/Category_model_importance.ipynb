# %%
# %load_ext autoreload
# %autoreload 2

import warnings
import pickle
warnings.filterwarnings("ignore")

import sys
from os.path import join

import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from tqdm import tqdm
# custom imports
SCRIPTS_PATH = '../scripts'
if SCRIPTS_PATH not in sys.path:
    sys.path.append(SCRIPTS_PATH)
    
import data_preparation
from text_utils import *

# %%
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sb
# %matplotlib inline

# %%
dataset1_df = pd.read_csv('../data/new_data/dataset1.csv', index_col=0) # отзывы
dataset2_df = pd.read_csv('../data/new_data/dataset2.csv', index_col=0) # характеристики товаров

compare_v3_df = pd.read_csv('../data/new_data/compare_v3.csv', sep=';', index_col=0) # сравнения товаров 
views_df = pd.read_csv('../data/new_data/views.csv', sep=';', index_col=0) # просмотры (сессия) пользователей

# %%
dataset1_df.head()
# Out:
#     PRODUCT  CATEGORY_ID  BRAND_ID  \
# 0  30024724      2060202      1900
# 1  30024724      2060202      1900
# 2  30024725      2060202      1900
# 3  30024727      2060101      1900
# 4  30024727      2060101      1900
#
#                                 CATEGORY_NAME            BRAND_NAME    TYPE  \
# 0  PRINTERS LASER                              Kyocera               REVIEW
# 1  PRINTERS LASER                              Kyocera               REVIEW
# 2  PRINTERS LASER                              Kyocera               REVIEW
# 3  ALL-IN-ONE LASER                            Kyocera               REVIEW
# 4  ALL-IN-ONE LASER                            Kyocera               REVIEW
#
#                                              SUBJECT  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  С такой вроде бы навороченной техникой все смо...
# 4                                                NaN
#
#                                                 TEXT        POSTED_DATE  \
# 0  Что особенно ценно - при профилактике принтера...  23.10.16 22:26:00
# 1  Он у нас три месяца в офисе стоит уже - большо...  17.04.16 11:17:42
# 2  Просто небо и земля с тем принтером, который у...  15.04.16 20:22:47
# 3  У нас в кабинете недавно его поставили. Первое...  18.04.16 20:01:57
# 4  Очень многофункциональная штука.  Есть все нео...  23.04.16 12:03:39
#
#    RATING                                           BENEFITS  \
# 0     5.0  хорошая скорость печати, двусторонняя печать, ...
# 1     5.0                                                NaN
# 2     4.0                                                NaN
# 3     5.0                                                NaN
# 4     5.0                                                NaN
#
#                                            DRAWBACKS  RECOMMENDED  \
# 0  Рядом "на стол" не поставишь, место много зани...          1.0
# 1                                                NaN          NaN
# 2                                                NaN          NaN
# 3                                                NaN          NaN
# 4                                                NaN          NaN
#
#    LIKES_COUNT  DISLIKES_COUNT
# 0          2.0             0.0
# 1          0.0             2.0
# 2          0.0             1.0
# 3          0.0             0.0
# 4          1.0             0.0

# %%
temp_df = dataset1_df.groupby('PRODUCT').agg({'RATING':'mean', 'CATEGORY_ID':'count'})

# %%
temp_df[temp_df['CATEGORY_ID']>4].sort_values(by='RATING')
# Out:
#             RATING  CATEGORY_ID
# PRODUCT
# 20022309  1.000000            5
# 50048292  1.000000            7
# 50037426  1.000000           11
# 30015709  1.000000            7
# 50037074  1.000000            5
# 50049381  1.000000           12
# 50045082  1.166667            6
# 20022764  1.166667            6
# 50041631  1.166667            6
# 50045164  1.200000            5
# 20021851  1.200000            5
# 50045441  1.300000           10
# 50034594  1.333333            6
# 50049382  1.363636           11
# 30018965  1.375000            8
# 20027874  1.400000            5
# 20027627  1.400000            5
# 50039853  1.428571            7
# 50037653  1.428571            7
# 20026370  1.454545           11
# 50035201  1.470588           17
# 50039621  1.500000            6
# 50044843  1.500000           12
# 50039078  1.500000            8
# 20024469  1.500000            8
# 20035611  1.555556            9
# 30020577  1.571429            7
# 50039867  1.600000            5
# 50046371  1.600000            5
# 20035444  1.600000           20
# ...            ...          ...
# 20034685  5.000000            9
# 20031081  5.000000           10
# 10007542  5.000000           13
# 10007271  5.000000            9
# 20034692  5.000000            5
# 20034693  5.000000            8
# 20036674  5.000000            5
# 30023973  5.000000            6
# 11031929  5.000000            6
# 10007297  5.000000           11
# 20022058  5.000000            6
# 10007323  5.000000            5
# 30023935  5.000000            8
# 20026753  5.000000            8
# 10007364  5.000000           11
# 20034968  5.000000            5
# 10007386  5.000000            5
# 10007434  5.000000            6
# 50038428  5.000000            7
# 50038381  5.000000            5
# 10007435  5.000000            6
# 10007436  5.000000            5
# 50038353  5.000000            5
# 20026712  5.000000            5
# 20026694  5.000000            6
# 10007510  5.000000            5
# 30026143  5.000000           25
# 10007541  5.000000           11
# 50038310  5.000000            5
# 20032937  5.000000            5
#
# [14360 rows x 2 columns]

# %% [raw]
# # ignore
# products_weight = dataset2_df[dataset2_df['NAME']=='Операционная система']
# training_data = dataset1_df[['TEXT','PRODUCT']]
# training_data = training_data[training_data['PRODUCT'].isin(products_weight['PRODUCT'])]
#
# training_data = pd.merge(training_data, products_weight[['PRODUCT', 'VALUE']], on='PRODUCT')
# training_data.shape

# %%
# %%time

from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.linear_model import SGDClassifier
from pymystem3 import Mystem


class ClassificationModel:
    def __init__(self):
        self.mystem = Mystem()
        self.pipeline_stages =  [('vect', CountVectorizer(max_features=100000)),
                                 ('tfidf', TfidfTransformer()),
                                 ('clf', SGDClassifier(n_jobs=-1))]

        self.pipeline = Pipeline(self.pipeline_stages)
    
    def preprocess_text(self, text):
        return ''.join(self.mystem.lemmatize(text)).strip()
    
    def fit(self, x_train, y_train):
        x_train = [self.preprocess_text(x) for x in x_train]
        self.pipeline.fit(x_train, np.round(y_train))
        vect_voc = self.pipeline_stages[0][1].vocabulary_
        self.inverse_vocabulary = dict(zip(vect_voc.values(), vect_voc.keys()))
    
    def get_words_importance(self, coef_idx):
        clf = self.pipeline_stages[-1][1]
        coeff = [(self.inverse_vocabulary[i], clf.coef_[coef_idx][i]) for i in range(clf.coef_[0].shape[0])]
        return sorted(coeff, key=lambda x: x[1], reverse=True)
    
    def predict(self, x_data):
        x_data = [self.preprocess_text(x) for x in x_data]
        return self.pipeline.predict(x_data)
    
def features_extractor(dataset):
    return training_data['TEXT'], training_data['NAME']


clf_model = ClassificationModel()
# Out:
# CPU times: user 0 ns, sys: 4 ms, total: 4 ms
# Wall time: 312 µs

# %%
#X_data = training_data['TEXT']
# y_data = training_data['VALUE']

X_data = dataset1_df['TEXT']
y_data = dataset1_df['CATEGORY_NAME'].str.strip()

clf_model.pipeline.fit(X_data, y_data)

vect_voc = clf_model.pipeline_stages[0][1].vocabulary_
clf_model.inverse_vocabulary = dict(zip(vect_voc.values(), vect_voc.keys()))

# %%
list(clf_model.pipeline_stages[-1][1].classes_)
# Out:
# ['3D AUDIO SYSTEM',
#  '3D CAMCORDERS DIGITAL',
#  '3D DIGITAL CAMERAS',
#  'ACCESSORIES FOR ACOUSTIC SYSTEMS',
#  'ACCESSORIES FOR APPLE SMARTPHONES',
#  'ACCESSORIES FOR APPLE TABLETS',
#  'ACCESSORIES FOR CAMCORDERS',
#  'ACCESSORIES FOR CLIMATE TECHNICS',
#  'ACCESSORIES FOR COOKERS & OVENS',
#  'ACCESSORIES FOR COSMETIC TOOLS',
#  'ACCESSORIES FOR DISH WASHERS',
#  'ACCESSORIES FOR E-BOOKS',
#  'ACCESSORIES FOR GAMES CONSOLES DS',
#  'ACCESSORIES FOR HAIR CARE',
#  'ACCESSORIES FOR HOODS',
#  'ACCESSORIES FOR IRON BOARDS',
#  'ACCESSORIES FOR MACBOOK',
#  'ACCESSORIES FOR MICROWAVES OVENS',
#  'ACCESSORIES FOR MUSICAL INSTRUMENTS',
#  'ACCESSORIES FOR NINTENDO WII',
#  'ACCESSORIES FOR PLAYSTATION 2 (PS 2)',
#  'ACCESSORIES FOR PLAYSTATION 3 (PS 3)',
#  'ACCESSORIES FOR PLAYSTATION 4 (PS 4)',
#  'ACCESSORIES FOR PLAYSTATION PORTABLE (PS',
#  'ACCESSORIES FOR PORTABLE SPEAKERS',
#  'ACCESSORIES FOR PRINTERS',
#  'ACCESSORIES FOR RADIO-CONTROLLED DEVICES',
#  'ACCESSORIES FOR REFREGIRATORS',
#  'ACCESSORIES FOR SHA',
#  'ACCESSORIES FOR SMARTPHONES AND MOBILE P',
#  'ACCESSORIES FOR TABLET COMPUTERS',
#  'ACCESSORIES FOR TV AND DVD',
#  'ACCESSORIES FOR VACUUM CLEANERS',
#  'ACCESSORIES FOR VIDEOPROJECTORS',
#  'ACCESSORIES FOR WASHING MACHINES',
#  'ACCESSORIES FOR XBOX 360',
#  'ACCESSORIES FOR XBOXONE',
#  'ACOUSTICS FOR TV',
#  'AIR CLEANERS',
#  'ALL-IN-ONE INKJET',
#  'ALL-IN-ONE LASER',
#  'APPLE IPHONE',
#  'AUDIO/CD RECORDED',
#  'AUDIOBOOKS',
#  'AUTO ELECTRONICS OBSOLETE TECHNOLOGIES',
#  'BAGS',
#  'BAKING FORM',
#  'BATTERIES AND CHARGERS',
#  'BATTERYS',
#  'BLU-RAY-VIDEO DISKS',
#  'BOILER WATER HEATERS',
#  'BOOKS',
#  'BOOMBOX WITH BLUETOOTH',
#  'BREAD MAKERS',
#  'BUILT-IN COOKTOPS',
#  'BUILT-IN DISHWASHER',
#  'BUILT-IN HOODS',
#  'BUILT-IN OVEN',
#  'BUILT-IN REFRIGERATORS/FREEZERS',
#  'BUILT-IN WASHING MACHINES',
#  'CABLES FOR PORTABLE DEVICES',
#  'CABLES FOR THE COMPUTER',
#  'CABLES/AV ADAPTERS',
#  'CAM',
#  'CAMCORDERS PREVIOUS TECHNOLOGIES',
#  'CAPPUCCINO&ESPRESSO MACHINES',
#  'CAR ACCESSORIES',
#  'CAR HOLDERS',
#  'CAR SPEAKERS',
#  'CERAMIC FAN HEATERS',
#  'CERTIFICATES',
#  'CHARGERS',
#  'CHILDREN CARE GOODS',
#  'CLEANING FOR AV',
#  'CLEANING FOR DIGITAL',
#  'CLOTHER DRIERS',
#  'COFFE GRINDERS',
#  'COFFEE PREPARATION ACCESSORIES',
#  'COFFEEMAKERS',
#  'COMMERCIAL TELEVISION',
#  'COMPACT BOILER WATER HEATERS',
#  'COMPACT PHOTOPRINTERS',
#  'COMPUTER ACCESSORIES',
#  'COMPUTER HANDSETS',
#  'COMPUTER SPEAKERS',
#  'COMPUTERS',
#  'COMPUTERS APPLE',
#  'COMPUTERS-MONOBLOCKS',
#  'CONVECTOR HEATERS',
#  'COOLERS',
#  'COSMETIC TOOLS',
#  'DEHUMIDIFIER',
#  'DESK FANS',
#  'DESKCOOKERS',
#  'DIGITAL CAMERAS COMPACT',
#  'DIGITAL COMPACT CAMERAS WITH CHANGEBLE L',
#  'DIGITAL PC GAMES',
#  'DIGITAL SERVICES FOR M_MOBILE',
#  'DIGITAL SERVICES FOR PC',
#  'DIGITAL SINGLE LENSE REFLEX CAMERAS',
#  'DIGITAL SOFT PC',
#  'DIGITAL VIDEO GAMES',
#  'DISH SET',
#  'DISHWASHER',
#  'DISKS / CASES FOR DISKS',
#  'DJ EQUIPMENT',
#  'DVD-RECODER WITH HDD',
#  'DVD-VIDEO DISKS',
#  'DVR',
#  'EE-BOOKS',
#  'ELECTRIC COOKERS',
#  'ELECTRIC GRILL',
#  'ELECTRONIC DICTIONARIES',
#  'EPILATORS ACCESSORIES',
#  "EPILATORS AND WOMEN'S SHAVERS",
#  'EXTERNAL HDD / CASES',
#  'FAN HEATERS',
#  'FAXES',
#  'FILTER FOR WASHINE MACHINES & DISHWASHER',
#  'FIREPLACES',
#  'FLASH CAMCORDERS ACTION',
#  'FLASH CAMCORDERS HD',
#  'FLASH CARD',
#  'FLOOR FANS',
#  'FLOWING WATER HEATERS',
#  'FOOD PROCESSORS',
#  'FREEZERS',
#  'FRYINGPAN',
#  'GADGETS',
#  'GAME ACCESSORIES FOR COMPUTERS',
#  'GAME CONSOLE DS',
#  'GAME CONSOLE GBA',
#  'GAME CONSOLE PS VITA',
#  'GAME CONSOLE PS1',
#  'GAME CONSOLE PS2',
#  'GAME CONSOLE PS3',
#  'GAME CONSOLE PS4',
#  'GAME CONSOLE PSP',
#  'GAME CONSOLE SEGA',
#  'GAME CONSOLE WII',
#  'GAME CONSOLE XBOX-360',
#  'GAME CONSOLE XBOXONE',
#  'GAMES BOX',
#  'GAS COOKERS',
#  'GENERAL ACCESSORIES FOR PHOTO & CAMCORDE',
#  'HAIR CARE',
#  'HAIR CUT',
#  'HANDSETS',
#  'HEADPHONES',
#  'HI-FI ACCESSORIES',
#  'HI-FI ACOUSTICS',
#  'HI-FI COMPONENTS',
#  'HI-FI SETS',
#  'HOME AUDIO',
#  'HOME VIDEO PROJECTORS',
#  'HOUSEHOLD EQUIPMENT',
#  'HUMIDIFIERS',
#  'HUMIDIFIERS-AIR CLEANERS',
#  'INFRARED GAS HEATERS',
#  'IONIZER',
#  'IRON BOARDS',
#  'IRONS',
#  'ISOTHERMAL CONTAINER',
#  'JUICE MAKERS',
#  'KETTLE/TEAPOT',
#  'KETTLES',
#  'KEYBOARDS',
#  'KITCHEN ACCESSORIES',
#  'KITCHEN SCALES',
#  'KITCHEN TECHNICS ACCESSORIES',
#  'KNIVES',
#  'LANDLE',
#  'LAPTOP ACCESSORIES',
#  'LED TV 15\\"-30\\"',
#  'LED TV 32\\"-38\\"',
#  'LED TV 39\\"-42\\"',
#  'LED TV 43\\"-50\\"',
#  'LED TV 51\\"-55\\"',
#  'LED TV 56\\"-65\\"',
#  'LED TV 66\\"+',
#  'LENSES AND FLASH',
#  'LID',
#  'LIGHTING / LAMPS',
#  'MEAT GRINDER',
#  'MEMORY CARD FOR PHOTO',
#  'MEMORY CARDS',
#  "MEN'S SHAVERS",
#  "MEN'S SHAVERS ACCESSORIES",
#  'MICATHERMIC HEATER',
#  'MICE',
#  'MICROWAVE OVENS SOLO',
#  'MICROWAVE OVENS WITH GRILL',
#  'MICROWAVE OVENS WITH GRILL & CONVECTION',
#  'MINI OVEN',
#  'MINIWASHING MACHINES',
#  'MIXERS/BLENDERS',
#  'MOBILE AIR CONDITIONERS',
#  'MOBILE PHONES',
#  'MONITORS',
#  'MP3-DISKS',
#  'MULTICOOKERS',
#  'MULTIMEDIA PROJECTORS',
#  'MUSICAL INSTRUMENTS',
#  'NAVIGATION SYSTEM',
#  'NETWORK EQUIPMENT',
#  'NEW PLANNAME COMP. TECHNIQUE 7',
#  'NEW PLANNAME PHOTO-AUTO 6',
#  'NEW PLANNAME TELECOM 8',
#  "NEW YEAR'S ACCESSORIES",
#  'NOTEBOOK',
#  'NOTEBOOK APPLE',
#  'OIL RADIATORS',
#  'OLED-TV 40\\" - 55\\"',
#  'OLED-TV 51\\"-55\\"',
#  'OLED-TV 56\\"-65\\"',
#  'ORAL CARE',
#  'ORAL CARE ACCESSORIES',
#  'ORIGINAL ACCESSORIES FOR SMARTPHONES',
#  'OTHER APPLE ACCESSORIES',
#  'OTHER APPLE DEVICES',
#  'OTHER DISH',
#  'OTHER GAME CONSOLES AND ACCESSORIES',
#  'OTHER OPTICAL TECHNICS',
#  'OTHERS BUILT-IN',
#  'OTHERS COMPUTERS',
#  'OTHERS SHA',
#  'OTHERS TELECOMMUNICATION PRODUCTS',
#  'OTHERS TELECOMMUNICATIONS',
#  'PACKAGE SERVICES FOR PC',
#  'PHONE ADDITIONAL DEVICES',
#  'PHOTO FRAMES AND COMPACT PHOTO PRINTERS',
#  'PHOTO PRINTING',
#  'PHOTOCAMERAS',
#  'PLASMA TV 42\\"-65\\"+',
#  'PLAYER APPLE',
#  'PORTABLE ACOUSTICS',
#  'PORTABLE AUDIO SYSTEM',
#  'PORTABLE PLAYERS+',
#  'POT',
#  'POWER BANK',
#  'PREMIUM PHOTO',
#  'PREMIUM PHOTOACCESSORIES',
#  'PRINTERS INKJET',
#  'PRINTERS LASER',
#  'PRODUCTS OF CELLULAR OPERATORS',
#  'PRODUCTS TO CONNECT TO THE INTERNET',
#  'QUADROCOPTERS',
#  'QUARTZ HEATERS',
#  'RADIO TELEPHONE DECT',
#  'RADIO-CONTROLLED DEVICES',
#  'RADIOS',
#  'RADIOSTATIONS',
#  'REFRIGERATORS COMBI (BOTTOM-FREEZE)',
#  'REFRIGERATORS ONE DOOR',
#  'REFRIGERATORS PORTABLE',
#  'REFRIGERATORS SIDE-BY-SIDE AND MULTIDOOR',
#  'REFRIGERATORS TOP (TOP-FREEZE)',
#  'SAMSUNG SMARTPHONES',
#  'SCALES FLOOR',
#  'SCANERS',
#  'SECURITY SYSTEM',
#  'SEWING-MACHINES',
#  'SMART TV DONGLES',
#  'SMART WATCHES',
#  'SMARTPHONES',
#  'SOFTWARE',
#  'SOFTWARE SERVICES FOR M.MOBILE',
#  'SOUNDBAR',
#  'SPECIALISED VACUUM CLEANERS AND CAR WASH',
#  'SPLIT SYSTEMS',
#  'SPLIT SYSTEMS (INVERTER)',
#  'STANDS & FURNITURE FOR TV',
#  'SURGE PROTECTORS / EXTENDERS',
#  'TABLET COMPUTERS',
#  'TABLET COMPUTERS APPLE',
#  'TECHNIQUE LOEWE',
#  'TELEPHONES WIRE',
#  'TELESCOPES',
#  'THEATRE FLOOR STANDING ACOUSTICS',
#  'THEATRE SHELF STANDING ACOUSTICS',
#  'THERMOS',
#  'TOASTERS',
#  'TOWER FANS',
#  'TOYS',
#  'TRIPODS',
#  'TV MOUNTING',
#  'TV TUNER DVB-T2',
#  'VACUUM CLEANERS WASHING',
#  'VACUUM CLEANERS WITH A DUST COLLECTOR',
#  'VACUUM CLEANERS WITH THE CONTAINER FOR A',
#  'VAIO NOTEBOOKS',
#  'VIDEO GAMES FOR NINTENDO WII',
#  'VIDEO GAMES FOR PLAYSTATION 2',
#  'VIDEO GAMES FOR PLAYSTATION 3',
#  'VIDEO GAMES FOR PLAYSTATION 4',
#  'VIDEO GAMES FOR PLAYSTATION PORTABLE',
#  'VIDEO GAMES FOR PS VITA',
#  'VIDEO GAMES FOR X-BOX 360',
#  'VIDEO GAMES FORX-BOX ONE',
#  'VIDEO TECHNICS',
#  'VOICE RECODER',
#  'WASHING MACHINES',
#  'WATER FILTERS',
#  'WATER HEATERS GAS',
#  'WEB-CAM',
#  'WHETHER STATION',
#  'WINDOW AIR CONDITIONERS',
#  'WINE & BEVERAGE COOLERS',
#  'XEROX',
#  'АКСЕССУАРЫ ДЛЯ FUJIFILM INSTAX']

# %%
cat_id = list(clf_model.pipeline_stages[-1][1].classes_).index('SMARTPHONES')
tablet_keywords = clf_model.get_words_importance(cat_id)
tablet_keywords[:100]
# Out:
# [('смартфон', 3.2070159836651086),
#  ('новинке', 1.5102663298988503),
#  ('xiaomi', 1.3034761929789995),
#  ('телефон', 1.1760754025064071),
#  ('фронтальная', 0.97215511994372472),
#  ('redmi', 0.86432315840739238),
#  ('мнение', 0.79269780697509074),
#  ('мп', 0.77007407350922819),
#  ('htc', 0.75551377735007763),
#  ('камера', 0.74250504097177217),
#  ('4a', 0.70359570983741904),
#  ('коммуникатор', 0.70239346580845108),
#  ('приложения', 0.67965757983623576),
#  ('симки', 0.64838952746486767),
#  ('батарея', 0.58856291060419863),
#  ('смартфона', 0.58555807189506781),
#  ('приложений', 0.57410396170463063),
#  ('андроид', 0.56323140182829001),
#  ('nokia', 0.53744097992930862),
#  ('телефоном', 0.53645560604228482),
#  ('смартфонов', 0.51104386060228479),
#  ('телефона', 0.48031927947278519),
#  ('сим', 0.47926772618158653),
#  ('4g', 0.47755243569828854),
#  ('селфи', 0.47475937436075821),
#  ('смарт', 0.4746405616619353),
#  ('gps', 0.47178871075026063),
#  ('задняя', 0.46630326797133997),
#  ('смартфоне', 0.46448514023245352),
#  ('телефоне', 0.44607661148162536),
#  ('lumia', 0.4333928714888251),
#  ('основная', 0.42878711659444391),
#  ('динамик', 0.4272564178967026),
#  ('суток', 0.4263696838918315),
#  ('активном', 0.42474219007299574),
#  ('13', 0.42470963004970275),
#  ('оболочка', 0.42311807244400712),
#  ('android', 0.42241803639605868),
#  ('экран', 0.40873108530798441),
#  ('камеры', 0.40265996582204616),
#  ('сутки', 0.39590930291105658),
#  ('huawei', 0.39439536825438432),
#  ('фронталка', 0.39302023674654579),
#  ('жесту', 0.39024371639726191),
#  ('13мп', 0.38244641684515929),
#  ('phone', 0.38050795706155144),
#  ('дня', 0.37707288217240997),
#  ('руке', 0.35610592578570466),
#  ('сенсор', 0.35481962023134195),
#  ('шустрый', 0.35254577911956253),
#  ('батареи', 0.35038466208018548),
#  ('фронтальной', 0.34744849224950097),
#  ('смартфоном', 0.34047367591665811),
#  ('5мп', 0.3392378945257658),
#  ('интернетом', 0.33608321070338348),
#  ('xperia', 0.33299603461622629),
#  ('lg', 0.33166610792114182),
#  ('дисплей', 0.32621767139370034),
#  ('honor', 0.32532457146997573),
#  ('смартфончик', 0.32166958407154606),
#  ('день', 0.32159977946952195),
#  ('батарейка', 0.32158480596677386),
#  ('крышка', 0.32023013984413923),
#  ('ос', 0.31710814322568187),
#  ('вспышка', 0.31404776199351597),
#  ('тел', 0.31250336598735967),
#  ('lenovo', 0.31228680065374276),
#  ('интернет', 0.30883993396469184),
#  ('контакты', 0.30112276943620891),
#  ('андройд', 0.3010674389084384),
#  ('симок', 0.29721032003393444),
#  ('смартфоны', 0.2956493083961334),
#  ('sim', 0.29536860574845464),
#  ('интерфейс', 0.29224463582683835),
#  ('памяти', 0.28966255987530987),
#  ('встроенной', 0.28910841729616543),
#  ('звонков', 0.28674974965344263),
#  ('андроида', 0.28402705108941217),
#  ('кпк', 0.28116989001475629),
#  ('lte', 0.28007749362618745),
#  ('задней', 0.27907847808956676),
#  ('аппарат', 0.27564651780602867),
#  ('сеть', 0.27518281586154408),
#  ('телефону', 0.27215327908256759),
#  ('смарта', 0.26846185080681795),
#  ('обе', 0.26753946147213137),
#  ('блокировки', 0.26622654947843832),
#  ('телефоны', 0.26458523645314075),
#  ('мач', 0.26201553703799396),
#  ('телефонов', 0.26081715231682906),
#  ('5800', 0.25268644399423679),
#  ('640', 0.25259561260376001),
#  ('звонки', 0.25145875958527569),
#  ('вспышки', 0.25027903391802775),
#  ('аппарата', 0.24849816592571075),
#  ('mobile', 0.24756747239498175),
#  ('интернете', 0.24581855162111979),
#  ('леново', 0.2450738843197027),
#  ('пользовании', 0.24429023432582339),
#  ('asus', 0.24226160263037114)]

# %%
from collections import OrderedDict

category_keywords = dict()
for idx, catergory_name in enumerate(clf_model.pipeline_stages[-1][1].classes_):
    words_importance = clf_model.get_words_importance(idx)
    words_importance = filter(lambda x:x[1]!=0, words_importance)
    category_keywords[catergory_name] = OrderedDict(words_importance)

# %%
import pickle
pickle.dump(category_keywords, open('../dumps/category_keywords.pkl', 'wb'))

# %%
import eli5

product_text = dataset1_df[dataset1_df['PRODUCT']==20035335]['TEXT'].sample(1).iloc[0]

eli5.show_prediction(clf_model.pipeline_stages[-1][1],
                     product_text, vec=clf_model.pipeline_stages[0][1],
                     target_names=list(clf_model.pipeline_stages[-1][1].classes_),
                     targets=['IRONS'])
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=IRONS
#
# </b>
#
#
#     (score <b>10.958</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +12.024
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 96.33%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.066
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 98.41%); opacity: 0.80" title="0.063">купила</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="6.287">утюг</span><span style="opacity: 0.80"> в </span><span style="background-color: hsl(120, 100.00%, 99.77%); opacity: 0.80" title="0.004">декабре</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.90%); opacity: 0.80" title="-0.037">по</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.87%); opacity: 0.80" title="0.095">акции</span><span style="opacity: 0.80">, </span><span style="background-color: hsl(0, 100.00%, 99.33%); opacity: 0.80" title="-0.018">активно</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.06%); opacity: 0.80" title="-0.030">использую</span><span style="opacity: 0.80"> 3 </span><span style="background-color: hsl(0, 100.00%, 99.08%); opacity: 0.80" title="-0.029">месяца</span><span style="opacity: 0.80">, </span><span style="background-color: hsl(120, 100.00%, 99.49%); opacity: 0.80" title="0.012">за</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.38%); opacity: 0.80" title="0.016">это</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.12%); opacity: 0.80" title="0.027">время</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.33%); opacity: 0.81" title="0.292">перегладила</span><span style="opacity: 0.80"> в </span><span style="background-color: hsl(120, 100.00%, 98.85%); opacity: 0.80" title="0.039">доме</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.49%); opacity: 0.80" title="0.012">все</span><span style="opacity: 0.80">, </span><span style="background-color: hsl(120, 100.00%, 98.89%); opacity: 0.80" title="0.037">что</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.70%); opacity: 0.80" title="-0.006">только</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.64%); opacity: 0.80" title="0.008">возможно</span><span style="opacity: 0.80">. </span><span style="background-color: hsl(120, 100.00%, 98.65%); opacity: 0.80" title="0.050">единственный</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.27%); opacity: 0.80" title="-0.021">недостаток</span><span style="opacity: 0.80"> - </span><span style="background-color: hsl(120, 100.00%, 99.54%); opacity: 0.80" title="0.011">ручка</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.47%); opacity: 0.80" title="0.013">влажная</span><span style="opacity: 0.80">, </span><span style="background-color: hsl(120, 100.00%, 99.60%); opacity: 0.80" title="0.009">если</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.88%); opacity: 0.80" title="-0.038">пользоваться</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 93.01%); opacity: 0.82" title="0.520">отпаривателем</span><span style="opacity: 0.80">. </span><span style="background-color: hsl(0, 100.00%, 99.33%); opacity: 0.80" title="-0.018">но</span><span style="opacity: 0.80"> у </span><span style="background-color: hsl(120, 100.00%, 98.77%); opacity: 0.80" title="0.043">всех</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 92.75%); opacity: 0.82" title="0.548">утюгов</span><span style="opacity: 0.80">, </span><span style="background-color: hsl(120, 100.00%, 99.78%); opacity: 0.80" title="0.004">которыми</span><span style="opacity: 0.80"> я </span><span style="background-color: hsl(120, 100.00%, 98.45%); opacity: 0.80" title="0.060">пользовалась</span><span style="opacity: 0.80"> </span><span style="background-c ...
